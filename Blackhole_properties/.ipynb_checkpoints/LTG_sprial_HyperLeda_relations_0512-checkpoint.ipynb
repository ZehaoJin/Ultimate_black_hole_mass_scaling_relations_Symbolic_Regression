# %%
import numpy as np
import pandas as pd
from pysr import PySRRegressor
from IPython.display import HTML
from matplotlib import pyplot as plt

from hyperfit.linfit import LinFit

import functions
import old_relations
import new_relations

# %%
df = pd.read_csv('SMBH_Data_0504.csv',header=1)

# %%
df.columns[3:20]
# Out:
# Index(['Type', 'ETG', 'Leda Type', 'T-type', 'T-type_std', 'Arm Class', 'Bar',
#        'Disk', 'Ring', 'Core', 'Multiple', 'Compactness', 'AGN', 'Pseudobulge',
#        'BCG', 'cD', 'M_BH'],
#       dtype='object')

# %%
df.columns[-39:-16]
# Out:
# Index(['brief', 'brief_std', 'ube', 'bve', 'mg2', 'mg2_std', 'dc', 'dc_std',
#        'ubtc', 'ubtc_std', 'bvtc', 'bvtc_std', 'bri25', 'm21c', 'm21c_std',
#        'hic', 'hic_std', 'mabs', 'mabs_std', 'blum', 'blum_std', 'logblum',
#        'logblum_std'],
#       dtype='object')

# %%
HTML(df.sort_values('M_BH').to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Galaxy</th>
#       <th>Morphology</th>
#       <th>Type</th>
#       <th>ETG</th>
#       <th>Leda Type</th>
#       <th>T-type</th>
#       <th>T-type_std</th>
#       <th>Arm Class</th>
#       <th>Bar</th>
#       <th>Disk</th>
#       <th>Ring</th>
#       <th>Core</th>
#       <th>Multiple</th>
#       <th>Compactness</th>
#       <th>AGN</th>
#       <th>Pseudobulge</th>
#       <th>BCG</th>
#       <th>cD</th>
#       <th>M_BH</th>
#       <th>M_BH_std</th>
#       <th>M*_sph</th>
#       <th>M*_sph_std</th>
#       <th>M*_disk</th>
#       <th>M*_disk_std</th>
#       <th>M*_gal</th>
#       <th>M*_gal_std</th>
#       <th>B/T</th>
#       <th>B/T_std</th>
#       <th>log_B/T</th>
#       <th>log_B/T_std</th>
#       <th>D/T</th>
#       <th>D/T_std</th>
#       <th>log_D/T</th>
#       <th>log_D/T_std</th>
#       <th>m_#_of_arms</th>
# ...

# %%
# M*_gal,tan_phi,log_v_max + dc blum mabs

# %%
functions.test_relation(['M*_gal','tan_phi','log_v_max',
                        'dc','bri25','mabs','logblum'],
                        operator='basic')
# Out:
# 37
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# WARNING: method definition for OneHotArray at /home/zj448/miniconda3/share/pysr/depot/packages/MicroCollections/yJPLe/src/onehot.jl:79 declares type variable N but does not use it.
# parameters:
# x 0 : M*_gal
# x 1 : tan_phi
# x 2 : log_v_max
# x 3 : dc
# x 4 : bri25
# x 5 : mabs
# x 6 : logblum
# Eq. selected rmse: 0.21002860265483445
# 2*x2*(1.842064915323365 - x1)
# Eq. 0 rmse: 0.4751391345291405
# 7.6255058276238215
# Eq. 1 rmse: 0.4258400264976487
# 0.69144593713084916*x0
# Eq. 2 rmse: 0.3551744383058346
# x2*(3.56698162569124 - x1)
# Eq. 3 rmse: 0.21002860265483445
# 2*x2*(1.842064915323365 - x1)
# Eq. 4 rmse: 0.1967586706240308
# (1.9249855917184429 - x1)*(-x1 + 2*x2)
# Eq. 5 rmse: 0.19638012327390342
# 2*x2*(1.908939130724019 - 1.2841493036651033*x1)
# Eq. 6 rmse: 0.1823936761181781
# ...

# %%
functions.test_relation(['M*_gal','tan_phi','log_v_max',
                        'dc','bri25','mabs','logblum','bvtc'],
                        operator='basic')
# Out:
# 30
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# parameters:
# x 0 : M*_gal
# x 1 : tan_phi
# x 2 : log_v_max
# x 3 : dc
# x 4 : bri25
# x 5 : mabs
# x 6 : logblum
# x 7 : bvtc
# Eq. selected rmse: 0.15582089030999002
# x2*(x2 + 0.1288877352294736)/(x1 + 0.8896143230428322) + 2.4142785673951628
# Eq. 0 rmse: 0.47172590837167555
# 7.669445323324019
# Eq. 1 rmse: 0.37434514760132653
# x0 - 3.15660339215356
# Eq. 2 rmse: 0.2194150267724436
# 9.378224231142866 - 7.816062047723758*x1
# Eq. 3 rmse: 0.17813512636456186
# x2*(2.8508140952865393 - 2.7435039309220564*x1) + 2.300905884704338
# Eq. 4 rmse: 0.15582089030999002
# x2*(x2 + 0.1288877352294736)/(x1 + 0.8896143230428322) + 2.4142785673951628
# Eq. 5 rmse: 0.15483837165382067
# x2*(-x1*(2.546719263647044 + 1.812602288381738/x3) + 2.8508140952865393) + 2.300905884704338
# ...

# %%
functions.test_relation(['M*_gal','tan_phi','log_v_max',
                        'dc','bri25','mabs','logblum'],
                        operator='simp',ncyclesperiteration=5000,niterations=100,adaptive_parsimony_scaling=1000)
# Out:
# 37
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# parameters:
# x 0 : M*_gal
# x 1 : tan_phi
# x 2 : log_v_max
# x 3 : dc
# x 4 : bri25
# x 5 : mabs
# x 6 : logblum
# Eq. selected rmse: 0.1907025771623276
# 1.9425880150444281*x2*(x3/x1)**(x2/x4)
# Eq. 0 rmse: 0.4751391345291405
# 7.625505827623828
# Eq. 1 rmse: 0.33744167567443945
# 2.37642780421006**x2
# Eq. 2 rmse: 0.2979421832815372
# x1**x1*x6
# Eq. 3 rmse: 0.2587277564160165
# x2*(-x1 + x2 + 1.118052481445965)
# Eq. 4 rmse: 0.211087433384869
# 2*x2*(1.8401682788965534 - x1)
# Eq. 5 rmse: 0.1907025771623276
# 1.9425880150444281*x2*(x3/x1)**(x2/x4)
# Eq. 6 rmse: 0.17802212021420175
# x2*(2.3512420740561275 + 0.37713012582691724/(x1 + 0.14109616187434593 + 2.058002553522167/x3))
# Eq. 7 rmse: 0.17290475471052608
# ...

# %%
functions.test_relation(['M*_gal','tan_phi','log_v_max',
                        'dc','bri25','mabs','logblum','bvtc'],
                        operator='simp',ncyclesperiteration=5000,niterations=100,adaptive_parsimony_scaling=1000)
# Out:
# 30
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# parameters:
# x 0 : M*_gal
# x 1 : tan_phi
# x 2 : log_v_max
# x 3 : dc
# x 4 : bri25
# x 5 : mabs
# x 6 : logblum
# x 7 : bvtc
# Eq. selected rmse: 0.14328689050022225
# (3.956824581438449 - x1)*(-x1 + x2) - 0.2858335053432031
# Eq. 0 rmse: 0.4717259083716755
# 7.669445323323739
# Eq. 1 rmse: 0.2985531137087974
# 2.3826602249184132**x2
# Eq. 2 rmse: 0.22054136659205356
# 9.378224346666478 - 7.717151279077979*x1
# Eq. 3 rmse: 0.2147809979814522
# x2*(-x1 + x2 + 1.1492961181197643)
# Eq. 4 rmse: 0.17064177284832335
# x2*(0.12392784058494852**(x1 - 0.17638485103311094) + x2)
# Eq. 5 rmse: 0.14328689050022225
# (3.956824581438449 - x1)*(-x1 + x2) - 0.2858335053432031
# Eq. 6 rmse: 0.14254877842634767
# x2*(((0.19207903596052042/x1)**x1)**(x2 + x7) + 2.353427262414871)
# ...

# %%
functions.test_relation(['tan_phi','log_v_max',
                        'dc','bri25','mabs','logblum'],
                        operator='basic',ncyclesperiteration=5000,niterations=100,adaptive_parsimony_scaling=1000)
# Out:
# 41
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# parameters:
# x 0 : tan_phi
# x 1 : log_v_max
# x 2 : dc
# x 3 : bri25
# x 4 : mabs
# x 5 : logblum
# Eq. selected rmse: 0.20084132620214323
# -3.4764190502127796*x0 + x1*(3.8004918446149523 - x0)
# Eq. 0 rmse: 0.4740121357107357
# 7.624611006426257
# Eq. 1 rmse: 0.3905924913403227
# 3.2107659232848544*x1
# Eq. 2 rmse: 0.25968843131013325
# 9.270079993020678 - 7.4277451457686645*x0
# Eq. 3 rmse: 0.20084132620214323
# -3.4764190502127796*x0 + x1*(3.8004918446149523 - x0)
# Eq. 4 rmse: 0.20054532906668374
# -x0*x1**2 + x1**2 + 3.3484036815896221
# Eq. 5 rmse: 0.20012317564745774
# x1*(0.4227663340707774*x0**2 - 2.721313198455895*x0 + 3.830745468436829)
# Eq. 6 rmse: 0.18137953982742502
# -x1**2*(x0 + 1.3928249937901174/x2) + x1**2 + 3.5661710441981355

# %%
functions.test_relation(['tan_phi','log_v_max',
                        'dc','bri25'],
                        operator='basic',ncyclesperiteration=5000,niterations=100,adaptive_parsimony_scaling=1000)
# Out:
# 41
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# parameters:
# x 0 : tan_phi
# x 1 : log_v_max
# x 2 : dc
# x 3 : bri25
# Eq. selected rmse: 0.20255451143595724
# -5.5659604690122216*x0 + 3.7829802345061108*x1
# Eq. 0 rmse: 0.4740121357107357
# 7.62461100642666
# Eq. 1 rmse: 0.3780468404575936
# 3.2526278659366903*x1
# Eq. 2 rmse: 0.25968843131013336
# 9.270080003343283 - 7.427745191216259*x0
# Eq. 3 rmse: 0.2547728131863346
# x0*(x1 - 9.689887629489624) + 9.252941219701802
# Eq. 4 rmse: 0.20255451143595724
# -5.5659604690122216*x0 + 3.7829802345061108*x1
# Eq. 5 rmse: 0.2018379879787803
# -5.729620394821212*x0 + 3.792270225915636*x1
# Eq. 6 rmse: 0.20058594642913374
# -0.07766682258329509*x0 + (3.8179360955886197 - x0)*(-x0 + x1)
# Eq. 7 rmse: 0.19787616808277328
# ...

# %%
# have to remove 1 outliner...
catalog='SMBH_Data_0504.csv'
def hyperfit(paras,bounds,plot=True,df=pd.read_csv(catalog,header=1)):
    paras.append('M_BH')
    stds=[]
    for para in paras:
        stds.append(para+'_std')
    
    paras.append('bri25')
    
    df_=df[paras+stds].dropna(axis='index',how='any')
    paras=paras[:-1]
    df_=df_[paras+stds]
    
    print(len(df_))
    
    xs=np.array(df_[paras]).transpose()
    errs=np.array(df_[stds]).transpose()
    cov=np.zeros((len(paras),len(paras),len(df_)))
    for i in range(len(paras)):
        cov[i,i,:]=errs[i]**2

    hf = LinFit(xs, cov)

    mcmc_samples, mcmc_lnlike = hf.emcee(bounds, verbose=False)
    print(np.mean(mcmc_samples, axis=1), np.std(mcmc_samples, axis=1))


    if plot:
        c=np.mean(mcmc_samples, axis=1)
        y=xs[-1]
        y_pred=0
        for i in range(len(c)-2):
            y_pred+=c[i]*xs[i]
        y_pred+=c[-2]

    plt.figure(figsize=(8,6))
    plt.scatter(y,y_pred,label='predicted')
    plt.plot(np.linspace(y_pred.min(),y_pred.max()),np.linspace(y_pred.min(),y_pred.max()),ls='--',label='f(x)=x')
    plt.xlabel(r'True $\rm{log} M_{BH}$',fontsize=20)
    plt.ylabel(r'Predicted $\rm{log} M_{BH}$',fontsize=20)
    plt.legend()
    plt.show()

    w = 1/errs[-1]**2
    print('rmse:',np.sqrt(np.average((y-y_pred)**2,weights=w)))
    print('un-weight rmse:',np.sqrt(np.average((y-y_pred)**2)))
    return np.mean(mcmc_samples, axis=1), np.std(mcmc_samples, axis=1)

# %%
functions.test_relation(['tan_phi','log_v_max',
                        'dc','bri25'],
                        operator='basic')
#### Eq.9
#### hall_of_fame_2023-05-12_115932.269.csv
#### disregard current one
'''
def phi_v_dc_relation(tan_phi,log_v_max,dc):    
    a = -5.450424119169053
    b = 4.
    c = 0.007093803005968875
    d = -0.80629759313596731
    return a*tan_phi+b*log_v_max+c*dc+d
'''
# Out:
# 41
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# WARNING: method definition for OneHotArray at /home/zj448/miniconda3/share/pysr/depot/packages/MicroCollections/yJPLe/src/onehot.jl:79 declares type variable N but does not use it.
# parameters:
# x 0 : tan_phi
# x 1 : log_v_max
# x 2 : dc
# x 3 : bri25
# Eq. selected rmse: 0.21402824328882242
# -6.540103082732639*x0 + 2*x1 + 4.383004343869893
# Eq. 0 rmse: 0.4740121357107357
# 7.62461100642677
# Eq. 1 rmse: 0.4303447574477273
# 7.846141087806019 - x0
# Eq. 2 rmse: 0.26146750783363004
# 9.148840311985241 - 6.862360066784496*x0
# Eq. 3 rmse: 0.21402824328882242
# -6.540103082732639*x0 + 2*x1 + 4.383004343869893
# Eq. 4 rmse: 0.21402824328882233
# -6.540103068326998*x0 + 2*x1 + 4.383004340520809
# Eq. 5 rmse: 0.20254665720754375
# -5.652461023426235*x0 + 4*x1 - 0.5040713045375144
# ...

# %%
hyperfit(paras=['tan_phi','log_v_max'],bounds = ((-5.7,-5.6),(3.9, 4.1),(-0.6,-0.4),(1.0e-5, 1.0)),plot=True)
# Out:
# 41
# /home/zj448/miniconda3/lib/python3.9/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# [-6.15067993  4.00954898 -0.54673486  0.24291215] [0.61103117 0.08483061 0.0698568  0.07165881]
# rmse: 0.2425468841994531
# un-weight rmse: 0.3584419370964767
# (array([-6.15067993,  4.00954898, -0.54673486,  0.24291215]),
#  array([0.61103117, 0.08483061, 0.0698568 , 0.07165881]))

# %%
hyperfit(paras=['tan_phi','log_v_max','dc'],bounds = ((-5.455, -5.445),(3.999, 4.001),(0.007,0.00711),(-0.81,-0.80),(1.0e-5, 1.0)),plot=True)
# Out:
# 41
# /home/zj448/miniconda3/lib/python3.9/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# [-5.44199453  3.98049913  0.00703695 -0.80260886  0.24463702] [2.98620208e-02 1.86739092e-02 6.80103658e-05 5.19849374e-03
#  6.12629522e-02]
# rmse: 0.19230933370386855
# un-weight rmse: 0.3565836938807016
# (array([-5.44199453,  3.98049913,  0.00703695, -0.80260886,  0.24463702]),
#  array([2.98620208e-02, 1.86739092e-02, 6.80103658e-05, 5.19849374e-03,
#         6.12629522e-02]))

# %%
functions.test_relation(['M*_gal','tan_phi',
                        'dc','bri25','mabs','logblum'],
                        operator='basic')
# Out:
# 42
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# parameters:
# x 0 : M*_gal
# x 1 : tan_phi
# x 2 : dc
# x 3 : bri25
# x 4 : mabs
# x 5 : logblum
# Eq. selected rmse: 0.27490161530047835
# 9.194472318133464 - 7.136516719535993*x1
# Eq. 0 rmse: 0.4849251585174577
# 7.610248120331402
# Eq. 1 rmse: 0.4083502755109858
# x0 - 3.242637578230838
# Eq. 2 rmse: 0.30123321340353393
# 6.738361840423067 + 0.1749678490397033/x1
# Eq. 3 rmse: 0.29694526104363245
# 8.758990085202246 - 5.136516719535993*x1
# Eq. 4 rmse: 0.27490161530047835
# 9.194472318133464 - 7.136516719535993*x1
# Eq. 5 rmse: 0.2717629547062471
# -3.550966645535241*x1 + 7.892396314295871 + 0.0967163131070635/x1
# Eq. 6 rmse: 0.2627934982067861
# -x1 + 7.36106883562252 - 10.670769712767953/x2 + 0.15816557072939566/x1
# Eq. 7 rmse: 0.26243863810030055
# ...

# %%
functions.test_relation(['M*_gal','tan_phi',
                        'dc','bri25'],
                        operator='basic')
# Out:
# 42
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# parameters:
# x 0 : M*_gal
# x 1 : tan_phi
# x 2 : dc
# x 3 : bri25
# Eq. selected rmse: 0.2761971214295425
# 9.3029152963506941 - 7.610248120331431*x1
# Eq. 0 rmse: 0.4849251585174577
# 7.610248120331664
# Eq. 1 rmse: 0.4083502755109858
# x0 - 3.242637580150486
# Eq. 2 rmse: 0.40006379364369454
# x0 - x1 - 3.1473819908363656
# Eq. 3 rmse: 0.2761971214295425
# 9.3029152963506941 - 7.610248120331431*x1
# Eq. 4 rmse: 0.2747765808939434
# -(7.610248120331431 - x1)*(x1 - 0.22241944667968938) + 7.610248120331431
# Eq. 5 rmse: 0.27421586769005457
# -(7.610248120331431 - 1.6419369670166626*x1)*(x1 - 0.22241944667968938) + 7.610248120331431
# Eq. 6 rmse: 0.26874062373628177
# -(x1 - 0.21589138707967676)*(-0.26872331992116116*x1*x2 + 8.412341251132858) + 7.610248120331431
# Eq. 7 rmse: 0.267970793428599
# ...

# %%
functions.test_relation(['M*_gal','tan_phi',
                        'dc','bri25'],
                        operator='basic',ncyclesperiteration=5000,niterations=200,adaptive_parsimony_scaling=1000)
# eq.8
# Out:
# 42
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# parameters:
# x 0 : M*_gal
# x 1 : tan_phi
# x 2 : dc
# x 3 : bri25
# Eq. selected rmse: 0.27490161530047835
# 9.194472311578066 - 7.1365166901664185*x1
# Eq. 0 rmse: 0.4849251585174577
# 7.610248120331726
# Eq. 1 rmse: 0.40835027551098574
# x0 - 3.242637578231249
# Eq. 2 rmse: 0.27490161530047835
# 9.194472311578066 - 7.1365166901664185*x1
# Eq. 3 rmse: 0.2728490967618134
# -6.766784489655965*x1 + 9.14457968423252 - 2.057059899790772/x2
# Eq. 4 rmse: 0.26964787713969474
# -6.7046243479996272*x1 + 9.194472314666504 - 0.14915078729181258*x3/x2
# Eq. 5 rmse: 0.2436414493403549
# -7.024721107584915*x1 + 9.14457968423252 + 0.1339129048129198/(x2 - x3 + 0.5861862927239267)
# Eq. 6 rmse: 0.24006513823756223
# ...

# %%
functions.test_relation(['tan_phi',
                        'dc','bri25'],
                        operator='basic')
# Out:
# 46
# /home/zj448/miniconda3/lib/python3.9/site-packages/pysr/sr.py:1257: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# parameters:
# x 0 : tan_phi
# x 1 : dc
# x 2 : bri25
# Eq. selected rmse: 0.277999832365243
# 9.182626099034618 - 7.070617492252175*x0
# Eq. 0 rmse: 0.4837736387601065
# 7.6095470260270845
# Eq. 1 rmse: 0.4391276791134871
# 7.832028171750773 - x0
# Eq. 2 rmse: 0.277999832365243
# 9.182626099034618 - 7.070617492252175*x0
# Eq. 3 rmse: 0.27723542880934343
# -164.4686545488647*x0/x2 + 9.18294223379939
# Eq. 4 rmse: 0.27040274131889114
# x0*(-6.280260494292732 - 18.34670522284418/x1) + 9.12919364820552
# Eq. 5 rmse: 0.26915160680320954
# x0*(x0 - 6.676189241066003 - 19.063081497320283/x1) + 9.169426588983468
# Eq. 6 rmse: 0.2680372973880125
# x0*(2*x0 - 7.072126541138664 - 19.7792102289467/x1) + 9.209659779705273
# Eq. 7 rmse: 0.2587629349349432
# ...
