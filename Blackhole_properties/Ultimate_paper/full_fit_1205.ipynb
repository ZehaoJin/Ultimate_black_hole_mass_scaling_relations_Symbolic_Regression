# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## development

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import re
import scipy.optimize as opt
from tqdm import tqdm
import sympy as sp
from sympy.parsing.sympy_parser import parse_expr
from sympy import lambdify

# %%
filename = 'pareto_low_adv_refit.csv'  
t_eq=pd.read_csv('/data/zj448/SR/Ultimate_paper/pareto_archive/'+filename)

df_full = pd.read_csv('SMBH_Data_03_06_24.csv',header=1)

# %%
temp_str=t_eq['variables'][3].split(' ')
for i in ['\'','{','}',',']:
    temp_str = [x.replace(i,'') for x in temp_str]

# %%
temp_str
# Out:
# ['x53', 'x69', 'x42']

# %%
# list all unique elements in t_eq['variables']
all_elements = []
for i in t_eq['variables']:
    temp_str=i.split(' ')
    for j in ['\'','{','}',',']:
        temp_str = [x.replace(j,'') for x in temp_str]
    all_elements += temp_str
all_elements = list(dict.fromkeys(all_elements))

# %%
low_scatter_para=['ETG','T-type','Bar', 'Disk', 'Ring', 'Core', 'Multiple', 'Compactness', 'AGN',
       'Pseudobulge', 'BCG', 'cD','M*_sph', 'M*_gal', 'log_B/T',
       'log_sigma0', 'log_R_e_sph_maj','log_R_e_sph_eq_kpc', 'log_n_sph_maj', 'log_n_sph_eq', 'log(I_e,sph,maj/M_Sun/pc^2)',
       'log(I_e,sph,eq/M_Sun/pc^2)', 'Concentration_Index',
       'avg_Rho_1kpc_Exact_All', 'r1_density_approx', 'log10(R10_kpc)',
       'logRho_R10_approx', 'log_rho10_Exact', 'log10(R90_kpc)',
       'logRho_R90_approx', 'log_rho_90_Exact_all', 'Rho_re_spatial',
       'SR_pc_All', 'Rho_SR_pc_All', 'CR_def1_approx_new',
       'Rho_cr_def1_approx_new', 'CR_def2_approx_new',
       'Rho_CR_def2_approx_new', 'Sr(pc)_2_using_Falserm_drho',
       'Log_Approx_Avg_density_10pc', 'log_Rho_e_Exact_new',
       'logRho_e_approx_New', 'logRho_soi_approx_new',
       'log_Rho_soi_exact_new', 'Avg_Rho_Re_Exact_all',
       'Avg_Rho_soi_exact_all', 'Avg_Rho_re_Exact_all', 'Rho_re_Exact_all',
       'Rho_r_soi_2BH_approx', 'Log_Avg_Rho_10kpc_approx',
       'Log_Avg_Rho_10kpc_exact_final', 'Log_Avg_Rho_100pc_approx',
       'Log_Avg_Rho_5kpc_approx', 'Log_Avg_rho_5kpc_exact_all', 'ube', 'bve',
       'dc', 'bvtc', 'bri25', 'mabs', 'blum', 'logblum', 'logSigma0sph',
       'LogSigma0', 'R10', 'logR10', 'logR10phi', 'Rh', 'logRh', 'logRhphi',
       'logHalo','B-V','V-[3.6]','GJC23W1-W2','GJC23W2-W3','GJC23log(M*,gal/M_sun)',
       'GJC23log(SFR)','GJC23log(sSFR)','log<Sigma>_e','log<Sigma>_h','M_BH']

easy_obs_para=['LogSigma0','Concentration_Index','logSigma0sph','log_sigma0','dc','logRhphi','M*_sph','ube','bri25','bve','bvtc','logR10phi','M*_gal','log_B/T',
 'logRh','log_n_sph_eq','blum','log_R_e_sph_maj','logblum','log_n_sph_maj','logR10','Pseudobulge','AGN','Multiple','Ring','BCG','Disk','cD',
 'Bar','Core','Compactness','ETG','T-type','log10(R10_kpc)','log10(R90_kpc)','B-V','V-[3.6]','GJC23W1-W2','GJC23W2-W3','GJC23log(M*,gal/M_sun)','M_BH']

#low_scatter_para.append('M_BH_std_sym')
#easy_obs_para.append('M_BH_std_sym')
std_white_list=['ube_std', 'bri25_std', 'bve_std', 'Pseudobulge_std', 'AGN_std', 'Multiple_std', 'Ring_std', 'BCG_std', 'Disk_std', 'cD_std', 'Bar_std', 'Core_std', 'Compactness_std', 'ETG_std', 'M_BH_std']

# %%
easy_obs_para_std=easy_obs_para.copy()
for i in easy_obs_para:
    easy_obs_para_std.append(i+'_std')

low_scatter_para.append('M_BH_std_sym')
easy_obs_para.append('M_BH_std_sym')

# remove std_white_list from easy_obs_para_std
for i in std_white_list:
    easy_obs_para_std.remove(i)

# %%
easy_obs_para_std
# Out:
# ['LogSigma0',
#  'Concentration_Index',
#  'logSigma0sph',
#  'log_sigma0',
#  'dc',
#  'logRhphi',
#  'M*_sph',
#  'ube',
#  'bri25',
#  'bve',
#  'bvtc',
#  'logR10phi',
#  'M*_gal',
#  'log_B/T',
#  'logRh',
#  'log_n_sph_eq',
#  'blum',
#  'log_R_e_sph_maj',
#  'logblum',
#  'log_n_sph_maj',
#  'logR10',
#  'Pseudobulge',
#  'AGN',
#  'Multiple',
#  'Ring',
#  'BCG',
#  'Disk',
#  'cD',
#  'Bar',
#  'Core',
#  'Compactness',
#  'ETG',
#  'T-type',
#  'log10(R10_kpc)',
#  'log10(R90_kpc)',
#  'B-V',
#  'V-[3.6]',
#  'GJC23W1-W2',
#  'GJC23W2-W3',
#  'GJC23log(M*,gal/M_sun)',
#  'M_BH',
#  'LogSigma0_std',
#  'Concentration_Index_std',
#  'logSigma0sph_std',
#  'log_sigma0_std',
#  'dc_std',
#  'logRhphi_std',
#  'M*_sph_std',
#  'bvtc_std',
#  'logR10phi_std',
#  'M*_gal_std',
#  'log_B/T_std',
#  'logRh_std',
#  'log_n_sph_eq_std',
#  'blum_std',
#  'log_R_e_sph_maj_std',
#  'logblum_std',
#  'log_n_sph_maj_std',
#  'logR10_std',
#  'T-type_std',
#  'log10(R10_kpc)_std',
#  'log10(R90_kpc)_std',
#  'B-V_std',
#  'V-[3.6]_std',
#  'GJC23W1-W2_std',
#  'GJC23W2-W3_std',
#  'GJC23log(M*,gal/M_sun)_std']

# %%
df=df_full[easy_obs_para]
df=df.dropna()
len(df)
# Out:
# 93

# %%
df=df_full[easy_obs_para_std]
# drop the column with all nan
df=df.dropna(axis=1,how='all')
df=df.dropna()
len(df)
# Out:
# 28

# %%
df=df_full[low_scatter_para]
df=df.dropna()
len(df)
# Out:
# 93

# %%
df=df_full[low_scatter_para+['logRho_soi_approx_new_std','Log_Avg_rho_5kpc_exact_all_std','logRhphi_std']]
df=df.dropna()
len(df)
# Out:
# 93

# %%
df=df[['M_BH','logRho_soi_approx_new','Log_Avg_rho_5kpc_exact_all','logRhphi','M_BH_std_sym',
           'logRho_soi_approx_new_std','Log_Avg_rho_5kpc_exact_all_std','logRhphi_std']]
df
# Out:
#          M_BH  logRho_soi_approx_new  Log_Avg_rho_5kpc_exact_all   logRhphi  \
# 1    9.380211               2.426156                   -0.638676  10.782617
# 3    9.102971               2.371550                   -0.789930  10.892139
# 6    5.740000               2.866880                   -3.759670   9.627691
# 7    8.677184               2.197050                   -1.182099  10.908384
# 9    7.591065               4.674412                   -1.234999  10.571088
# ..        ...                    ...                         ...        ...
# 131  8.808460               2.659694                   -1.046558  10.802649
# 132  8.279168               3.619939                   -0.899206  10.883571
# 133  6.833669               3.185089                   -1.840809  10.535837
# 134  6.198130               2.014039                   -2.181465  10.477966
# 142  7.744293               3.165358                   -1.577750  10.629700
#
#      M_BH_std_sym  logRho_soi_approx_new_std  Log_Avg_rho_5kpc_exact_all_std  \
# 1        0.180956                   0.866987                        0.122041
# 3        0.086075                   0.645526                        0.078167
# 6        0.103967                   0.428204                        0.065420
# 7        0.099526                   0.448971                        0.066468
# 9        0.194876                   0.896939                        0.080682
# ..            ...                        ...                             ...
# 131      0.027143                   0.603377                        0.073080
# 132      0.052000                   0.839854                        0.157888
# 133      0.101335                   0.403237                        0.070204
# 134      0.108574                   0.476131                        0.069536
# 142      0.177666                   0.461412                        0.079779
#
#      logRhphi_std
# 1        0.170524
# 3        0.141405
# 6        0.160544
# 7        0.130661
# 9        0.152391
# ..            ...
# 131      0.170416
# 132      0.236217
# 133      0.143617
# 134      0.150851
# 142      0.212677
#
# [93 rows x 8 columns]

# %%
t_eq.iloc[3]
# Out:
# complexity                                                                17
# loss                                                                 0.09062
# score                                                               0.001319
# equation                   ((((0.13631070516777483 - ((x42 * (0.556125855...
# sympy_format               -0.46524650939821102*x42 + x53 + x69 + 0.39610...
# lambda_format              PySRFunction(X=>-0.46524650939821102*x42 + x53...
# number_constants                                                           6
# variables                                              {'x53', 'x69', 'x42'}
# number_variables                                                           3
# unique_number_variables                                                    3
# evolutions                                                                 0
# iterations                                                                 0
# fitting_format                                  -p[1]*x42 + x53 + x69 + p[0]
# num_fitting_variables                                                      2
# initial_constant_guess            ['0.396106010486694', '0.465246509398211']
# LLL                                                               -92.883246
# intrinsic_scatter                                                   0.476855
# refit_equation             -0.37531951644419825*x42 + x53 + x69 + 0.06735...
# refit_wrmse                                                         0.096992
# Name: 3, dtype: object

# %%
def str2equ(equation):
    return lambdify(list(dict.fromkeys(re.findall(r'\bx\d+',equation))),equation)

func = str2equ(t_eq.iloc[3]['fitting_format'])

# %%
t_eq.iloc[3]['refit_equation']
# Out:
# '-0.37531951644419825*x42 + x53 + x69 + 0.067354207487827'

# %%
func
# Out:
# <function _lambdifygenerated(x42, x53, x69)>

# %%
def func(p,i):
    return -p[0]*p[2+i+1] + p[93+2+i+1] + p[93*2+2+i+1] + p[1]


def loglikelihood(p):
    term0 = np.log(2*np.pi)*len(df)*(t_eq.iloc[3]['unique_number_variables']+1)

    term1 = (np.log(df['M_BH_std_sym']**2+p[2]**2)).sum()
    term1 += np.log(df['logRho_soi_approx_new_std']**2).sum()
    term1 += np.log(df['Log_Avg_rho_5kpc_exact_all_std']**2).sum()
    term1 += np.log(df['logRhphi_std']**2).sum()

    
    term2 = 0
    for i in range(len(df)):
        term2 += (df['M_BH'].iloc[i] - func(p,i))**2/(df['M_BH_std_sym'].iloc[i]**2+p[2]**2)
    
    term3 = 0
    for i in range(len(df)):
        term3 += ((df['logRho_soi_approx_new'].iloc[i]-p[2+i+1])/df['logRho_soi_approx_new_std'].iloc[i])**2
        term3 += ((df['Log_Avg_rho_5kpc_exact_all'].iloc[i]-p[93+2+i+1])/df['Log_Avg_rho_5kpc_exact_all_std'].iloc[i])**2
        term3 += ((df['logRhphi'].iloc[i]-p[93*2+2+i+1])/df['logRhphi_std'].iloc[i])**2

    print(p[:4],term0+term1+term2+term3)
    return term0+term1+term2+term3

current_parameter_vector = np.zeros(93*3+3)
current_parameter_vector[:2] = np.array([0.37531951644419825,0.067354207487827])
current_parameter_vector[2] = t_eq.iloc[3]['intrinsic_scatter']
current_parameter_vector[3:3+93] = df['logRho_soi_approx_new']
current_parameter_vector[3+93:3+93*2] = df['Log_Avg_rho_5kpc_exact_all']
current_parameter_vector[3+93*2:3+93*3] = df['logRhphi']

# 3 sigma bounds depending on std
bounds=[(-np.inf,np.inf)]*3+[(i-3*j,i+3*j) for i,j in zip(df['logRho_soi_approx_new'],df['logRho_soi_approx_new_std'])]+[(i-3*j,i+3*j) for i,j in zip(df['Log_Avg_rho_5kpc_exact_all'],df['Log_Avg_rho_5kpc_exact_all_std'])]+[(i-3*j,i+3*j) for i,j in zip(df['logRhphi'],df['logRhphi_std'])]
result = opt.minimize(loglikelihood, current_parameter_vector, method='L-BFGS-B', tol=1e-5, options={'maxiter':5e4, 'maxfev':5e4, 'adaptive':True},bounds=bounds)
# Out:
# /tmp/ipykernel_3666995/3929580410.py:36: OptimizeWarning: Unknown solver options: maxfev, adaptive
#   result = opt.minimize(loglikelihood, current_parameter_vector, method='L-BFGS-B', tol=1e-5, options={'maxiter':5e4, 'maxfev':5e4, 'adaptive':True},bounds=bounds)
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916380719
# [0.37531953 0.06735421 0.47685453 2.42615624] -186.73969586586202
# [0.37531952 0.06735422 0.47685453 2.42615624] -186.7396916380719
# [0.37531952 0.06735421 0.47685454 2.42615624] -186.7396929972639
# [0.37531952 0.06735421 0.47685453 2.42615625] -186.73969164466442
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969165356004
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969162002575
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916570462
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164842336
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916547447
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969167040713
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916490425
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916700014
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916466951
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163446782
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164297088
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916463949
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164073316
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164022384
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163744871
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916037978
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916378029
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916395601
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969162928773
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163866292
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164017495
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916586057
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164198132
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163469536
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916482421
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969165414533
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969162722213
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916571644
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163130081
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164298802
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163720955
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916204954
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916381243
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916156552
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916380163
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163601427
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969165524093
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164080526
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916524835
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163372394
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916568864
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969165055922
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969165899598
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163612804
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969165079495
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163937363
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163164554
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164081635
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164151103
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969163677435
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164010944
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916420784
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164300055
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916522525
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.7396916391533
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969167339223
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164715783
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969167567265
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164480204
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969165482166
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969164422044
# [0.37531952 0.06735421 0.47685453 2.42615624] -186.73969
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640733599286
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640723699345
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664073292776
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640750354776
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640683089304
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640744898075
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.666407300904
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640743827196
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664076171292
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664075808686
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640732882775
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664073260713
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074260618
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640745506106
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640750050396
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640746698965
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664075034097
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074475802
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640748934594
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664075670119
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074733549
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664076331273
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074534365
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074844913
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640737445357
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640747886515
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074755374
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074616974
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640745897837
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664075301742
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640728252946
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074768061
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640741422077
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640739469733
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640738094236
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640745223026
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.666407402284
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640746599353
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640745469965
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640747985275
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664073899826
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664073647797
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640742683626
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640747165
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074484489
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640742840747
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074015008
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664073417943
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074325299
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074721731
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074859593
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640702608424
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.666407393173
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.666407544536
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664075110281
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640756458435
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074157381
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664072818149
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640755630215
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074507362
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640740884213
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074202689
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074830569
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640744357125
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640743814776
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640716329414
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074344868
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074294707
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.666407447989
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640746121504
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640745834695
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640747961713
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640745414406
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640752255273
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074446919
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.666407424682
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074376557
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640744726055
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640746284816
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074632763
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074473075
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640745583663
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074487543
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640745390623
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074169779
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640750782227
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640753337833
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664073844655
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074645191
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640745942516
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640748382827
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640741756424
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074683
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640742580785
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074386614
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664072744085
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074671485
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640679974444
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.666407449001
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640734454637
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.666407474195
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664076514056
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664076708423
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074747631
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.6664074310136
# [5.47218713e-01 6.73542075e-02 1.75472097e-03 2.44124111e+00] -432.66640750597514

# %%
import torch
from torch import nn, optim

# Convert the dataframe to PyTorch tensors
M_BH = torch.tensor(df['M_BH'].values, dtype=torch.float32)
logRho_soi_approx_new = torch.tensor(df['logRho_soi_approx_new'].values, dtype=torch.float32)
Log_Avg_rho_5kpc_exact_all = torch.tensor(df['Log_Avg_rho_5kpc_exact_all'].values, dtype=torch.float32)
logRhphi = torch.tensor(df['logRhphi'].values, dtype=torch.float32)
M_BH_std_sym = torch.tensor(df['M_BH_std_sym'].values, dtype=torch.float32)
logRho_soi_approx_new_std = torch.tensor(df['logRho_soi_approx_new_std'].values, dtype=torch.float32)
Log_Avg_rho_5kpc_exact_all_std = torch.tensor(df['Log_Avg_rho_5kpc_exact_all_std'].values, dtype=torch.float32)
logRhphi_std = torch.tensor(df['logRhphi_std'].values, dtype=torch.float32)

# Define the model
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.p0 = nn.Parameter(torch.tensor(0.37531952, dtype=torch.float32))
        self.p1 = nn.Parameter(torch.tensor(0.06735421, dtype=torch.float32))
        self.p2 = nn.Parameter(torch.tensor(t_eq.iloc[3]['intrinsic_scatter'], dtype=torch.float32))
        self.p3 = nn.Parameter(logRho_soi_approx_new.clone())
        self.p4 = nn.Parameter(Log_Avg_rho_5kpc_exact_all.clone())
        self.p5 = nn.Parameter(logRhphi.clone())

    def forward(self, i):
        return -self.p0 * self.p3[i] + self.p4[i] + self.p5[i] + self.p1

# Instantiate the model
model = Model()

# Define the loss function
def loglikelihood():
    term0 = torch.log(torch.tensor(2 * torch.pi)) * len(df) * (t_eq.iloc[3]['unique_number_variables'] + 1)

    term1 = (torch.log(M_BH_std_sym**2 + model.p2**2)).sum()
    term1 += torch.log(logRho_soi_approx_new_std**2).sum()
    term1 += torch.log(Log_Avg_rho_5kpc_exact_all_std**2).sum()
    term1 += torch.log(logRhphi_std**2).sum()

    term2 = ((M_BH - model(torch.arange(len(df))))**2 / (M_BH_std_sym**2 + model.p2**2)).sum()

    term3 = (((logRho_soi_approx_new - model.p3) / logRho_soi_approx_new_std)**2).sum()
    term3 += (((Log_Avg_rho_5kpc_exact_all - model.p4) / Log_Avg_rho_5kpc_exact_all_std)**2).sum()
    term3 += (((logRhphi - model.p5) / logRhphi_std)**2).sum()

    return term0 + term1 + term2 + term3

# Define the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.01)

# Training loop
for epoch in range(10000):
    optimizer.zero_grad()
    loss = loglikelihood()
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        print(f'Epoch {epoch}, Loss: {loss.item()}', model.p0.item(), model.p1.item(), model.p2.item())

# Get the optimized parameters
optimized_params = {name: param.data for name, param in model.named_parameters()}
print(optimized_params)
# Out:
# Epoch 0, Loss: -222.39947509765625 0.36531955003738403 0.0773540586233139 0.4868542551994324
# Epoch 100, Loss: -451.10516357421875 0.5519313216209412 0.5108887553215027 -0.0022468941751867533
# Epoch 200, Loss: -472.1434020996094 0.647580623626709 0.7757081985473633 -1.3643246347783133e-05
# Epoch 300, Loss: -477.9832763671875 0.7039250731468201 0.9386817812919617 7.531031798180265e-08
# Epoch 400, Loss: -480.66094970703125 0.7440189719200134 1.0556809902191162 -5.00826380367414e-10
# Epoch 500, Loss: -482.295166015625 0.7757135629653931 1.1479742527008057 2.1282871298655692e-12
# Epoch 600, Loss: -483.3565979003906 0.8013185262680054 1.2220890522003174 -1.3891941728363076e-14
# Epoch 700, Loss: -484.0957946777344 0.822776198387146 1.2845351696014404 2.643193112558891e-17
# Epoch 800, Loss: -484.615234375 0.8406569361686707 1.336247205734253 6.983330149811154e-20
# Epoch 900, Loss: -485.00787353515625 0.8564779758453369 1.3822686672210693 -6.854013304956202e-22
# Epoch 1000, Loss: -485.2975158691406 0.8697369694709778 1.42024564743042 4.822812373456292e-24
# Epoch 1100, Loss: -483.1196594238281 0.8828292489051819 1.4546464681625366 -6.117758684730436e-26
# Epoch 1200, Loss: -485.7032470703125 0.8921672105789185 1.4850314855575562 -2.713649013892469e-28
# Epoch 1300, Loss: -485.34033203125 0.9022507071495056 1.5120370388031006 -1.7722110183279456e-31
# Epoch 1400, Loss: -485.9561767578125 0.9097980856895447 1.5358952283859253 8.40889222645151e-33
# Epoch 1500, Loss: -485.6930847167969 0.9176139235496521 1.5582246780395508 1.813957678986682e-36
# Epoch 1600, Loss: -486.12384033203125 0.9242075681686401 1.5774043798446655 -2.169381317499096e-37
# Epoch 1700, Loss: -484.9898681640625 0.9296059608459473 1.5967282056808472 1.1049518650894048e-40
# Epoch 1800, Loss: -486.23675537109375 0.9359877705574036 1.6112794876098633 6.506228769860126e-42
# Epoch 1900, Loss: -486.2794189453125 0.9412134885787964 1.6264946460723877 1.6815581571897805e-44
# Epoch 2000, Loss: -486.3160705566406 0.9458788633346558 1.6397309303283691 1.401298464324817e-45
#         -1.0113, -1.4979, -2.3210, -0.7879, -0.6493, -1.6859, -1.6752, -1.9748,
#         -1.0253, -2.2410, -1.4618, -1.2356, -1.7608, -1.5472, -1.5863, -1.9264,
#         -1.7672, -1.9367, -1.9712, -1.8633, -1.7174, -2.0509, -2.3155, -1.6779,
#         -1.0477, -0.8953, -1.8523, -2.2153, -1.5764]), 'p5': tensor([10.7779, 10.8734,  9.7349, 10.8612, 10.6012, 10.6814, 10.9979, 10.4655,
#         10.5282, 10.8328, 10.2834, 10.7233, 10.7092, 10.8330, 10.3443, 10.1113,
#         10.2373, 10.6762, 10.7853, 10.5977, 10.7943, 10.5528, 10.4512, 10.4922,
#         10.1236, 10.5524, 10.6725, 10.2992, 10.7001, 10.4234, 10.6357, 10.5871,
#         10.4680, 10.7668, 10.5045, 10.0473, 10.6463, 10.4354, 10.6151, 10.5541,
#         10.2285, 10.5345, 10.7438, 10.5495, 10.7204, 10.7694, 10.5822, 10.4379,
#         10.0416, 10.3745, 10.4531, 10.7367, 10.1781, 10.3832, 10.4947, 10.8058,
#         10.8234, 10.7219, 10.6081, 10.8011, 10.5094, 10.5961, 10.8355, 10.5251,
#         10.8613, 10.6051,  9.8548, 10.6205, 10.5769,  9.8388, 10.3005, 10.4795,
#         10.6630,  9.8883, 10.7016, 10.7316, 10.4228, 10.5239, 10.5233, 10.0980,
#         10.3082, 10.3694, 10.4961, 10.4380, 10.1610, 10.0198, 10.0247, 10.4998,
#         10.7966, 10.8923, 10.4876, 10.3186, 10.6395])}

# %%
df['M_BH']-model(torch.arange(len(df))).detach().numpy()
# Out:
# 1     -0.005317
# 3     -0.006938
# 6      0.044948
# 7     -0.027396
# 9      0.049277
#          ...
# 131   -0.000165
# 132    0.000413
# 133   -0.024014
# 134   -0.082542
# 142    0.006799
# Name: M_BH, Length: 93, dtype: float64

# %%
plt.errorbar(df['logRho_soi_approx_new'],df['M_BH'],xerr=df['logRho_soi_approx_new_std'],yerr=df['M_BH_std_sym'],fmt='o',label='data',alpha=0.5)
plt.scatter(df['logRho_soi_approx_new'],str2equ(t_eq.iloc[3]['refit_equation'])(df['logRho_soi_approx_new'],df['Log_Avg_rho_5kpc_exact_all'],df['logRhphi']),label='old fit',c='r',s=10)
plt.scatter(model.p3.detach().numpy(),model(torch.arange(len(df))).detach().numpy(),label='new fit_true_x',c='g',s=10)
plt.scatter(df['logRho_soi_approx_new'],model(torch.arange(len(df))).detach().numpy(),label='new fit_data_x',c='b',s=10)
plt.xlabel('logRho_soi_approx_new')
plt.ylabel('M_BH')
plt.legend()

# %%
plt.errorbar(df['logRho_soi_approx_new'],df['M_BH'],xerr=df['logRho_soi_approx_new_std'],yerr=df['M_BH_std_sym'],fmt='o',label='data',alpha=0.5)
plt.scatter(df['logRho_soi_approx_new'],str2equ(t_eq.iloc[3]['refit_equation'])(df['logRho_soi_approx_new'],df['Log_Avg_rho_5kpc_exact_all'],df['logRhphi']),label='old fit',c='r',s=10)
plt.scatter(result.x[3:3+93],
            -result.x[0]*result.x[3:3+93] + result.x[93*1+3:3+93*2] + result.x[93*2+3:3+93*3] + result.x[1],
            label='new fit_true_x',c='g',s=10)
plt.scatter(df['logRho_soi_approx_new'],
            -result.x[0]*result.x[3:3+93] + result.x[93*1+3:3+93*2] + result.x[93*2+3:3+93*3] + result.x[1],
            label='new fit_data_x',c='b',s=10)
plt.xlabel('logRho_soi_approx_new')
plt.ylabel('M_BH')
plt.legend()

# %%
view_equation(3)
# Out:
# equation: -0.37531951644419825*x42 + x53 + x69 + 0.067354207487827
# -0.37531951644419825*x42 + x53 + x69 + 0.067354207487827
# x42 : logRho_soi_approx_new
# x53 : Log_Avg_rho_5kpc_exact_all
# x69 : logRhphi
# intrinsic scatter: 0.4768545318665391
# wrmse: 0.0969918257634491
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AIC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 view_equation(3)
#
# Cell In[12], line 11, in view_equation(index, var_list, t_eq)
#       9 print('intrinsic scatter:',t_eq.iloc[index]['intrinsic_scatter'])
#      10 print('wrmse:',t_eq.iloc[index]['refit_wrmse'])
# ---> 11 print('AIC:',t_eq.iloc[index]['AIC'])
#      12 print('BIC:',t_eq.iloc[index]['BIC'])
#      13 print('DOF:',t_eq.iloc[index]['DOF'])
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:1112, in Series.__getitem__(self, key)
#    1109     return self._values[key]
#    1111 elif key_is_scalar:
# -> 1112     return self._get_value(key)
#    1114 # Convert generator to list before going through hashable part
#    1115 # (We will iterate through the generator there to check for slices)
#    1116 if is_iterator(key):
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:1228, in Series._get_value(self, label, takeable)
#    1225     return self._values[label]
#    1227 # Similar to Index.get_value, but we do not fall back to positional
# -> 1228 loc = self.index.get_loc(label)
#    1230 if is_integer(loc):
#    1231     return self._values[loc]
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'AIC'

# %%
t_eq['LLL']=0.
t_eq['intrinsic_scatter']=0.
t_eq['refit_equation']=''
t_eq['refit_wrmse']=0.

number_matching_pattern = r"(?<![a-zA-Z0-9_.])[+-]?(\d+\.\d+|\.\d+|\d+\.|\d+)(?:[eE][-+]?\d+)?"


def predict(equation):
    func=str2equ(equation)
    labels = re.findall(r'x(\d+)', equation)
    labels = list(dict.fromkeys(labels))
    labels = [int(label) for label in labels]

    x=[]
    for i in range(len(labels)):
        x.append(df[low_scatter_para[labels[i]]])

    return func(*x)

def str2equ(equation):
    return lambdify(list(dict.fromkeys(re.findall(r'\bx\d+',equation))),equation)

def wrmse(y,y_pred,w):
    return np.average((y-y_pred)**2,weights=w)

mu_obs = df['M_BH']
sigma_y_obs2 = df['M_BH_std_sym']*df['M_BH_std_sym']
w=1/sigma_y_obs2

for row in tqdm(t_eq.iterrows(),total=len(t_eq)):

    equation = row[1]['fitting_format']

    variable_list=[]
    for i in range(row[1]['num_fitting_variables']):
        variable_list.append('p['+str(i)+']')
    
    constants = row[1]['initial_constant_guess']
    constants = eval(constants)
    
    print(equation)

    labels = re.findall(r'x(\d+)', equation)
    labels = list(dict.fromkeys(labels))
    labels = [int(label) for label in labels]

    x=[]
    for i in range(len(labels)):
        x.append(df[low_scatter_para[labels[i]]])

    mu_obs = df['M_BH']

    sigma_y_obs2 = df['M_BH_std_sym']*df['M_BH_std_sym']

    ##############################
    def loglikelihood(p):

        equation_=equation

        # swap constants in for p[i]
        for i in range(len(variable_list)):
            equation_ = equation_.replace(variable_list[i],str(p[i]))

        #print(equation_)

        func = str2equ(equation_)

        mu_pred = func(*x)
        sigma_y =  np.sqrt(sigma_y_obs2 + p[-1]*p[-1])
        #sigma_y =  np.sqrt(sigma_y_obs2)
        norm_residuals = (mu_obs - mu_pred) / sigma_y

        log_l = -0.5*len(df)*np.log(2*np.pi) -np.log(sigma_y).sum() - 0.5*(norm_residuals*norm_residuals).sum()

        #print(log_l)
        return -log_l
    ###############################


    for i in range(len(constants)):
        constants[i]=np.float64(constants[i])
    current_parameter_vector=np.array(constants)
    current_parameter_vector=np.append(current_parameter_vector,0.3) # last p is intrinsic scatter


    result = opt.minimize(loglikelihood, current_parameter_vector, method='Nelder-Mead', tol=1e-5, options={'maxiter':5e4, 'maxfev':5e4, 'adaptive':True})

    new_equation = equation
    for i in range(len(variable_list)):
        new_equation = new_equation.replace(variable_list[i],str(result.x[i]))
    t_eq.loc[row[0],'refit_equation']=new_equation

    refit_wrmse = wrmse(mu_obs,predict(t_eq.iloc[row[0]]['refit_equation']),w)
    if np.isnan(refit_wrmse):
        t_eq.loc[row[0],'refit_wrmse']=np.nan
        t_eq.loc[row[0],'LLL']=np.nan
        t_eq.loc[row[0],'intrinsic_scatter']=np.nan
    
    else:
        t_eq.loc[row[0],'refit_wrmse']=refit_wrmse
        t_eq.loc[row[0],'LLL']=-loglikelihood(current_parameter_vector)
        t_eq.loc[row[0],'intrinsic_scatter']=result.x[-1]
# Out:
#   0%|          | 0/1042 [00:00<?, ?it/s]
#   0%|          | 2/1042 [00:00<01:21, 12.70it/s]
# x66
# x73 + p[0]
# -p[1]*x42 + x53 + x69 + p[0]
# -p[2]*x42 + x53 + x69 + p[1] - p[4]/(p[3]*x51 + p[0])
#   0%|          | 4/1042 [00:02<10:12,  1.69it/s]
# p[4]*exp(exp(p[0]/(p[6] - p[1]*x52)**p[5])) + p[2] + log10(p[3]*x23)/x43
#   0%|          | 4/1042 [00:05<24:14,  1.40s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 87
#      83 current_parameter_vector=np.array(constants)
#      84 current_parameter_vector=np.append(current_parameter_vector,0.3) # last p is intrinsic scatter
# ---> 87 result = opt.minimize(loglikelihood, current_parameter_vector, method='Nelder-Mead', tol=1e-5, options={'maxiter':5e4, 'maxfev':5e4, 'adaptive':True})
#      89 new_equation = equation
#      90 for i in range(len(variable_list)):
#
# File ~/miniconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py:698, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     695 callback = _wrap_callback(callback, meth)
#     697 if meth == 'nelder-mead':
# --> 698     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     699                                **options)
#     700 elif meth == 'powell':
#     701     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/miniconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py:924, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     922 if bounds is not None:
#     923     xr = np.clip(xr, lower_bound, upper_bound)
# --> 924 fxr = func(xr)
#     925 doshrink = 0
#     927 if fxr < fsim[0]:
#
# File ~/miniconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py:620, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     618 ncalls[0] += 1
#     619 # A copy of x is sent to the user function (gh13740)
# --> 620 fx = function(np.copy(x), *(wrapper_args + args))
#     621 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     622 # backwards-compatibility, also allow np.array([1.3]),
#     623 # np.array([[1.3]]) etc.
#     624 if not np.isscalar(fx):
#
# Cell In[5], line 70, in loglikelihood(p)
#      67 func = str2equ(equation_)
#      69 mu_pred = func(*x)
# ---> 70 sigma_y =  np.sqrt(sigma_y_obs2 + p[-1]*p[-1])
#      71 #sigma_y =  np.sqrt(sigma_y_obs2)
#      72 norm_residuals = (mu_obs - mu_pred) / sigma_y
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:2168, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2164 @final
#    2165 def __array_ufunc__(
#    2166     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2167 ):
# -> 2168     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:414, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     411         result = default_array_ufunc(inputs[0], ufunc, method, *inputs, **kwargs)
#     412         # e.g. np.negative (only one reached), with "where" and "out" in kwargs
# --> 414 result = reconstruct(result)
#     415 return result
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:343, in array_ufunc.<locals>.reconstruct(result)
#     339 if ufunc.nout > 1:
#     340     # np.modf, np.frexp, np.divmod
#     341     return tuple(_reconstruct(x) for x in result)
# --> 343 return _reconstruct(result)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:358, in array_ufunc.<locals>._reconstruct(result)
#     355     result = self._constructor_from_mgr(result, axes=result.axes)
#     356 else:
#     357     # we converted an array, lost our axes
# --> 358     result = self._constructor(
#     359         result, **reconstruct_axes, **reconstruct_kwargs, copy=False
#     360     )
#     361 # TODO: When we support multiple values in __finalize__, this
#     362 # should pass alignable to `__finalize__` instead of self.
#     363 # Then `np.add(a, b)` would consider attrs from both a and b
#     364 # when a and b are NDFrames.
#     365 if len(alignable) == 1:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/series.py:588, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     586 manager = _get_option("mode.data_manager", silent=True)
#     587 if manager == "block":
# --> 588     data = SingleBlockManager.from_array(data, index, refs=refs)
#     589 elif manager == "array":
#     590     data = SingleArrayManager.from_array(data, index)
#
# KeyboardInterrupt:

# %%
t_eq
# Out:
#     complexity      loss     score  \
# 0            1  4.885951  0.000000
# 1            3  0.157051  1.718773
# 2            7  0.127908  0.058997
# 3           11  0.117943  0.020278
# 4           15  0.105290  0.028371
# ..         ...       ...       ...
# 59          13  0.021503  0.158455
# 60          19  0.019478  0.001638
# 61          21  0.019439  0.001002
# 62           4  0.115187  0.184676
# 63          19  0.015566  0.113730
#
#                                              equation  \
# 0                                                 x69
# 1                                         (x69 + x49)
# 2                         (((x12 + x49) - x73) - x17)
# 3   (((x69 + x49) - (log10(2.233044520137043) / ex...
# 4   ((((x13 + x53) + -0.4385317648318854) + (((0.5...
# ..                                                ...
# 59  (((x15 / 0.2781055358753451) + x19) - (log10(e...
# 60  (((x15 / 0.2781055358753451) + x19) - (log10((...
# 61  (((x15 / 0.2781055358753451) + x19) - (log10((...
# 62                   (log10(x15) * 23.41780258431442)
# 63  ((((x15 / 0.2928557769080886) + x19) - log10((...
#
#                                          sympy_format  \
# 0                                                 x69
# 1                                           x49 + x69
# 2                               x12 - x17 + x49 - x73
# 3   x49 + x69 - x73 - 0.8033659100247211*exp(-x56)...
# 4   x13 + x53 - x65 + (0.5787281095217448**x42)**1...
# ..                                                ...
# 59  3.595757261186734*x15 + x19 - log(exp(x42)/x21...
# 60  3.595757261186734*x15 + x19 - log((x2 + x8 + e...
# 61  3.595757261186734*x15 + x19 - log((x2 + x73 + ...
# 62                 23.41780258431442*log(x15)/log(10)
# 63  3.414650073007934*x15 + x19 - log(-0.768482453...
#
#                                         lambda_format  number_constants  \
# 0                                PySRFunction(X=>x69)                 0
# 1                          PySRFunction(X=>x49 + x69)                 0
# 2              PySRFunction(X=>x12 - x17 + x49 - x73)                 0
# 3   PySRFunction(X=>x49 + x69 - x73 - 0.8033659100...                 1
# 4   PySRFunction(X=>x13 + x53 - x65 + (0.578728109...                 4
# ..                                                ...               ...
# 59  PySRFunction(X=>3.595757261186734*x15 + x19 - ...                 2
# 60  PySRFunction(X=>3.595757261186734*x15 + x19 - ...                 3
# 61  PySRFunction(X=>3.595757261186734*x15 + x19 - ...                 3
# 62  PySRFunction(X=>23.41780258431442*log(x15)/log...                 1
# 63  PySRFunction(X=>3.414650073007934*x15 + x19 - ...                 3
#
#                                           variables  number_variables  \
# 0                                           {'x69'}                 1
# 1                                    {'x69', 'x49'}                 2
# 2                      {'x12', 'x49', 'x73', 'x17'}                 4
# 3                      {'x69', 'x49', 'x73', 'x56'}                 4
# 4                      {'x42', 'x65', 'x13', 'x53'}                 4
# ..                                              ...               ...
# 59                     {'x42', 'x19', 'x15', 'x21'}                 4
# 60         {'x42', 'x19', 'x2', 'x15', 'x21', 'x8'}                 6
# 61  {'x42', 'x19', 'x2', 'x15', 'x21', 'x8', 'x73'}                 7
# 62                                          {'x15'}                 1
# 63        {'x42', 'x9', 'x19', 'x15', 'x52', 'x21'}                 6
#
#     unique_number_variables  ...         aic  evolutions  iterations  \
# 0                         1  ...  908.786973           0           0
# 1                         2  ...   29.211556           0           0
# 2                         4  ...   23.790881           0           0
# 3                         4  ...   23.937366           0           0
# 4                         4  ...   27.583895           0           0
# ..                      ...  ...         ...         ...         ...
# 59                        4  ...    7.999501           0        1872
# 60                        6  ...    9.622973           0        1872
# 61                        7  ...    9.615720           0        1872
# 62                        1  ...   23.424861           0        1908
# 63                        6  ...    8.895362           0        2107
#
#                                        fitting_format num_fitting_variables  \
# 0                                                 x69                     0
# 1                                           x49 + x69                     0
# 2                               x12 - x17 + x49 - x73                     0
# 3             x49 + x69 - x73 - log10(p[0])*exp(-x56)                     1
# 4          x13 + x53 - x65 + (p[0]**x42)**p[1] - p[2]                     3
# ..                                                ...                   ...
# 59        p[0]*x15 + x19 - log10(exp(x42)/x21) + p[1]                     2
# 60  p[0]*x15 + x19 - log10((x2 + x8 + exp(x42) - p...                     3
# 61  p[0]*x15 + x19 - log10((x2 + x73 + x8 + exp(x4...                     3
# 62                                    p[0]*log10(x15)                     1
# 63  p[0]*x15 + x19 - log10(-p[1] + (-x52 + exp(x42...                     3
#
#                                initial_constant_guess          LLL  \
# 0                                                  [] -2644.193704
# 1                                                  []  -132.237834
# 2                                                  []  -113.504567
# 3                               ['2.233044520137043']          NaN
# 4   ['0.5787281095217448', '1.1072374946867565', '...   -75.852376
# ..                                                ...          ...
# 59       ['3.595757261186734', '0.38990846927012623']   -21.956161
# 60  ['3.595757261186734', '0.5889051845565962', '0...   -19.347105
# 61  ['3.595757261186734', '0.5889051845565962', '0...   -19.124593
# 62                              ['23.41780258431442']   -96.489604
# 63  ['3.414650073007934', '0.7684824535754969', '0...   -12.958851
#
#     intrinsic_scatter                                     refit_equation  \
# 0            2.495183                                                x69
# 1            0.575609                                          x49 + x69
# 2            0.536001                              x12 - x17 + x49 - x73
# 3                 NaN  x49 + x69 - x73 - log10(-0.19310753116117474)*...
# 4            0.438619  x13 + x53 - x65 + (0.566708231503907**x42)**0....
# ..                ...                                                ...
# 59           0.239813  3.422088700384049*x15 + x19 - log10(exp(x42)/x...
# 60           0.223603  3.321319736068659*x15 + x19 - log10((x2 + x8 +...
# 61           0.222083  3.310923746501202*x15 + x19 - log10((x2 + x73 ...
# 62           0.480893                       23.07503029440484*log10(x15)
# 63           0.198112  3.1717220830487545*x15 + x19 - log10(-0.702764...
#
#    refit_wrmse
# 0     4.885951
# 1     0.157051
# 2     0.127908
# 3          NaN
# 4     0.108121
# ..         ...
# 59    0.023058
# 60    0.020402
# 61    0.020351
# 62    0.130350
# 63    0.017436
#
# [64 rows x 21 columns]

# %% [markdown]
# ## Visualize the results of refitting.py

# %%
filename = 'pareto_low_adv_cleaned.csv'
t_eq = pd.read_csv('/data/zj448/SR/Ultimate_paper/pareto_archive/'+filename[:-12]+'_refit.csv')

# %%
# for i in range(100):
#     display(parse_expr(t_eq.iloc[i]['refit_equation']))

# %%
df_full = pd.read_csv('SMBH_Data_03_06_24.csv',header=1)

low_scatter_para=['ETG','T-type','Bar', 'Disk', 'Ring', 'Core', 'Multiple', 'Compactness', 'AGN',
       'Pseudobulge', 'BCG', 'cD','M*_sph', 'M*_gal', 'log_B/T',
       'log_sigma0', 'log_R_e_sph_maj','log_R_e_sph_eq_kpc', 'log_n_sph_maj', 'log_n_sph_eq', 'log(I_e,sph,maj/M_Sun/pc^2)',
       'log(I_e,sph,eq/M_Sun/pc^2)', 'Concentration_Index',
       'avg_Rho_1kpc_Exact_All', 'r1_density_approx', 'log10(R10_kpc)',
       'logRho_R10_approx', 'log_rho10_Exact', 'log10(R90_kpc)',
       'logRho_R90_approx', 'log_rho_90_Exact_all', 'Rho_re_spatial',
       'SR_pc_All', 'Rho_SR_pc_All', 'CR_def1_approx_new',
       'Rho_cr_def1_approx_new', 'CR_def2_approx_new',
       'Rho_CR_def2_approx_new', 'Sr(pc)_2_using_Falserm_drho',
       'Log_Approx_Avg_density_10pc', 'log_Rho_e_Exact_new',
       'logRho_e_approx_New', 'logRho_soi_approx_new',
       'log_Rho_soi_exact_new', 'Avg_Rho_Re_Exact_all',
       'Avg_Rho_soi_exact_all', 'Avg_Rho_re_Exact_all', 'Rho_re_Exact_all',
       'Rho_r_soi_2BH_approx', 'Log_Avg_Rho_10kpc_approx',
       'Log_Avg_Rho_10kpc_exact_final', 'Log_Avg_Rho_100pc_approx',
       'Log_Avg_Rho_5kpc_approx', 'Log_Avg_rho_5kpc_exact_all', 'ube', 'bve',
       'dc', 'bvtc', 'bri25', 'mabs', 'blum', 'logblum', 'logSigma0sph',
       'LogSigma0', 'R10', 'logR10', 'logR10phi', 'Rh', 'logRh', 'logRhphi',
       'logHalo','B-V','V-[3.6]','GJC23W1-W2','GJC23W2-W3','GJC23log(M*,gal/M_sun)',
       'GJC23log(SFR)','GJC23log(sSFR)','log<Sigma>_e','log<Sigma>_h','M_BH']

easy_obs_para=['LogSigma0','Concentration_Index','logSigma0sph','log_sigma0','dc','logRhphi','M*_sph','ube','bri25','bve','bvtc','logR10phi','M*_gal','log_B/T',
 'logRh','log_n_sph_eq','blum','log_R_e_sph_maj','logblum','log_n_sph_maj','logR10','Pseudobulge','AGN','Multiple','Ring','BCG','Disk','cD',
 'Bar','Core','Compactness','ETG','T-type','log10(R10_kpc)','log10(R90_kpc)','B-V','V-[3.6]','GJC23W1-W2','GJC23W2-W3','GJC23log(M*,gal/M_sun)','M_BH']

low_scatter_para.append('M_BH_std_sym')
easy_obs_para.append('M_BH_std_sym')

if 'low' in filename:
    df=df_full[low_scatter_para]
if 'easy' in filename:
    df=df_full[easy_obs_para]
df=df.dropna()
len(df)
# Out:
# 93

# %%
aic = -2*t_eq['LLL']+2*(t_eq['number_constants']+1)
t_eq['AIC']=aic
plt.scatter(t_eq['number_constants']+1,aic,c=t_eq['intrinsic_scatter'])
plt.xlabel('number of constants')
plt.ylabel('aic')
#plt.ylim(0,1000)
plt.yscale('log')
plt.colorbar().set_label('intrinsic scatter')

# %%
bic = -2*t_eq['LLL']+np.log(len(df))*(t_eq['number_constants']+1)
t_eq['BIC']=bic
plt.scatter(t_eq['number_constants']+1,bic,c=np.clip(t_eq['intrinsic_scatter'],0,0.5))
plt.xlabel('number of constants')
plt.ylabel('bic')
plt.ylim(0,400)
#plt.yscale('log')
plt.colorbar().set_label('intrinsic scatter')

# %%
dof = np.maximum(t_eq['number_constants'],t_eq['unique_number_variables'])+1
bic = np.array(-2*t_eq['LLL']+np.log(len(df))*dof)
t_eq['BIC']=bic
t_eq['DOF']=dof
plt.scatter(dof,bic,c=np.clip(t_eq['intrinsic_scatter'],0,0.5))
plt.xlabel('DOF')
plt.ylabel('bic')
plt.ylim(0,200)
#plt.yscale('log')
plt.colorbar().set_label('intrinsic scatter')

# %%
#aic.argmin()

# %%
bic.argsort(),bic[bic.argsort()]
# Out:
# (array([653, 652, 654, ...,  83, 995, 808]),
#  array([14.65025918, 17.13927014, 19.88061074, ...,         nan,
#                 nan,         nan]))

# %%
def view_equation(index,var_list=low_scatter_para,t_eq=t_eq):
    print('equation:',parse_expr(t_eq.iloc[index]['refit_equation']))
    display(parse_expr(t_eq.iloc[index]['refit_equation']))
    unique_variables = list(dict.fromkeys(re.findall(r'\bx\d+',t_eq.iloc[index]['refit_equation'])))
    #print(unique_variables)
    for i in range(len(unique_variables)):
        print(unique_variables[i],':',var_list[int(unique_variables[i][1:])])
    
    print('intrinsic scatter:',t_eq.iloc[index]['intrinsic_scatter'])
    print('wrmse:',t_eq.iloc[index]['refit_wrmse'])
    print('AIC:',t_eq.iloc[index]['AIC'])
    print('BIC:',t_eq.iloc[index]['BIC'])
    print('DOF:',t_eq.iloc[index]['DOF'])
    return None

# %%
print('Top1: index',bic.argsort()[0])
view_equation(bic.argsort()[0])
# Out:
# Top1: index 653
# equation: x15*(-x42/(x39 - 0.3167230750170285*x9**3.1865675724962137) + 3.1865675724962137) + 2.8150715678889657
# x15*(-x42/(x39 - 0.3167230750170285*x9**3.1865675724962137) + 3.1865675724962137) + 2.8150715678889657
# x15 : log_sigma0
# x42 : logRho_soi_approx_new
# x39 : Log_Approx_Avg_density_10pc
# x9 : Pseudobulge
# intrinsic scatter: 0.1103512466094481
# wrmse: 0.0110927234763246
# AIC: 1.9872617114596842
# BIC: 14.650259177225966
# DOF: 5

# %%
print('Top2: index',bic.argsort()[1])
view_equation(bic.argsort()[1])
# Out:
# Top2: index 652
# equation: x15*(-x42/(x39 - 0.3167222239015659*x9) + 3.1865666325111657) + 2.815073609119419
# x15*(-x42/(x39 - 0.3167222239015659*x9) + 3.1865666325111657) + 2.815073609119419
# x15 : log_sigma0
# x42 : logRho_soi_approx_new
# x39 : Log_Approx_Avg_density_10pc
# x9 : Pseudobulge
# intrinsic scatter: 0.1103507406208933
# wrmse: 0.0110927222533735
# AIC: 4.476272671352138
# BIC: 17.13927013711842
# DOF: 5

# %%
view_equation(bic.argsort()[2])
# Out:
# equation: x15*(-x42/(x39 - 0.43242462237853263*log10(exp(exp(x9))/x78)) + 3.271260721331937) + 2.596838320762477
# x15*(-x42/(x39 - 0.43242462237853263*log10(exp(exp(x9))/x78)) + 3.271260721331937) + 2.596838320762477
# x15 : log_sigma0
# x42 : logRho_soi_approx_new
# x39 : Log_Approx_Avg_density_10pc
# x9 : Pseudobulge
# x78 : log<Sigma>_e
# intrinsic scatter: 0.1137664802087505
# wrmse: 0.0093572027136544
# AIC: 2.6850137771690115
# BIC: 19.88061073608855
# DOF: 6

# %%
# [rank]^th best (in terms of [criteria]) with dof = [ndof]
ndof = 3
rank = 0
criteria = 'BIC'
t_eq_dof=t_eq[t_eq['DOF']==ndof]
view_equation(np.array(t_eq_dof[criteria]).argsort()[rank],t_eq=t_eq_dof)
# Out:
# equation: x39 - x42 + 7.417229618167781
# x39 - x42 + 7.417229618167781
# x39 : Log_Approx_Avg_density_10pc
# x42 : logRho_soi_approx_new
# intrinsic scatter: 0.3631079330428152
# wrmse: 0.073634484714086
# AIC: 100.81166275997816
# BIC: 110.40946123943793
# DOF: 3

# %%
# [rank]^th best (in terms of [criteria]) with number of variables = [nvar]
nvar = 1
rank = 0
criteria = 'BIC'
t_eq_var=t_eq[t_eq['unique_number_variables']==nvar]
view_equation(np.array(t_eq_var[criteria]).argsort()[rank],t_eq=t_eq_var)
# Out:
# equation: 0.5158951241986962*exp(x15) + 3.110169491559339
# 0.5158951241986962*exp(x15) + 3.110169491559339
# x15 : log_sigma0
# intrinsic scatter: 0.4232453072395818
# wrmse: 0.1074475028206057
# AIC: 159.493044939766
# BIC: 167.0908434192258
# DOF: 3

# %%
# [rank]^th best (in terms of [criteria]) with number of variables = [nvar]
nvar = 1
rank = 0
criteria = 'intrinsic_scatter'
t_eq_var=t_eq[t_eq['unique_number_variables']==nvar]
view_equation(np.array(t_eq_var[criteria]).argsort()[rank],t_eq=t_eq_var)
# Out:
# equation: 0.08732693504789066*x15**4.202422104946601 + 5.3324241699592125
# 0.08732693504789066*x15**4.202422104946601 + 5.3324241699592125
# x15 : log_sigma0
# intrinsic scatter: 0.4207947157917259
# wrmse: 0.1088582546123185
# AIC: 165.23148693565787
# BIC: 175.3618849082709
# DOF: 4

# %%
# [rank]^th best (in terms of [criteria]) with PySR complexity = [complexity]
complexity = 13
rank = 0
criteria = 'intrinsic_scatter'
t_eq_var=t_eq[t_eq['complexity']==complexity]
view_equation(np.array(t_eq_var[criteria]).argsort()[rank],t_eq=t_eq_var)
# Out:
# equation: x15*(-x42/(-0.17331871941783772**x71 + x39) + 3.189686636298002) + 2.885129763372674
# x15*(-x42/(-0.17331871941783772**x71 + x39) + 3.189686636298002) + 2.885129763372674
# x15 : log_sigma0
# x42 : logRho_soi_approx_new
# x71 : B-V
# x39 : Log_Approx_Avg_density_10pc
# intrinsic scatter: 0.1173553819869629
# wrmse: 0.0130950069051254
# AIC: 7.343308920304132
# BIC: 22.006306386070413
# DOF: 5

# %%
t_eq.columns
# Out:
# Index(['complexity', 'loss', 'score', 'equation', 'sympy_format',
#        'lambda_format', 'number_constants', 'variables', 'number_variables',
#        'unique_number_variables', 'evolutions', 'iterations', 'fitting_format',
#        'num_fitting_variables', 'initial_constant_guess', 'LLL',
#        'intrinsic_scatter', 'refit_equation', 'refit_wrmse', 'AIC', 'BIC',
#        'DOF'],
#       dtype='object')

# %%
plt.scatter(t_eq['intrinsic_scatter'],t_eq['BIC'])
plt.xlabel('intrinsic scatter')
plt.ylabel('BIC')
plt.yscale('log')
plt.xscale('log')

# %%
plt.scatter(t_eq['intrinsic_scatter'],t_eq['LLL'])
plt.xlabel('intrinsic scatter')
plt.ylabel('LLL')
plt.ylim(-2000,500)
#plt.yscale('log')
#plt.xscale('log')
# Out:
# (-2000.0, 500.0)

# %%
t_eq
# Out:
#       complexity      loss     score  \
# 0              1  2.422899  0.000000
# 1              3  0.793023  0.558434
# 2             13  0.095263  0.020015
# 3             17  0.090620  0.001319
# 4             19  0.090473  0.000813
# ...          ...       ...       ...
# 1017          23  0.011585  0.056926
# 1018          22  0.012256  0.010969
# 1019           6  0.044143  0.436999
# 1020          12  0.014401  0.510440
# 1021          20  0.010133  0.060767
#
#                                                equation  \
# 0                                                   x66
# 1                            (x73 - -8.377161567514106)
# 2     (((0.45731312294876897 - (((x42 - -0.353818247...
# 3     ((((0.13631070516777483 - ((x42 * (0.556125855...
# 4     ((((0.45731312294876897 - ((x42 * 0.5561258553...
# ...                                                 ...
# 1017  ((((x15 / 0.31852133710431946) + (exp(x79) ^ -...
# 1018  ((((x15 / 0.31852133710431946) + (x23 ^ -0.000...
# 1019          (log10(x15) * (26.037329703202072 - x42))
# 1020  (((x15 / 0.31852133710431946) + ((x39 - x42) /...
# 1021  ((((x15 / 0.31852133710431946) + (x23 ^ -0.000...
#
#                                            sympy_format  \
# 0                                                   x66
# 1                               x73 + 8.377161567514106
# 2     -0.45018841361960323*x42 + x53 + x69 + 0.29802...
# 3     -0.46524650939821102*x42 + x53 + x69 + 0.39610...
# 4     -0.45018841361960323*x42 + x53 + x69 + 0.45731...
# ...                                                 ...
# 1017  3.1395071020704912*x15 + (x39 - x42)/(x17/(x28...
# 1018  3.1395071020704912*x15 + x23**(-0.000395449818...
# 1019        (26.037329703202072 - x42)*log(x15)/log(10)
# 1020  3.1395071020704912*x15 + (x39 - x42)*exp(-x19)...
# 1021  3.1395071020704912*x15 + x23**(-0.000395449818...
#
#                                           lambda_format  number_constants  \
# 0                                  PySRFunction(X=>x66)                 0
# 1              PySRFunction(X=>x73 + 8.377161567514106)                 1
# 2     PySRFunction(X=>-0.45018841361960323*x42 + x53...                 4
# 3     PySRFunction(X=>-0.46524650939821102*x42 + x53...                 6
# 4     PySRFunction(X=>-0.45018841361960323*x42 + x53...                 6
# ...                                                 ...               ...
# 1017  PySRFunction(X=>3.1395071020704912*x15 + (x39 ...                 3
# 1018  PySRFunction(X=>3.1395071020704912*x15 + x23**...                 4
# 1019  PySRFunction(X=>(26.037329703202072 - x42)*log...                 1
# 1020  PySRFunction(X=>3.1395071020704912*x15 + (x39 ...                 2
# 1021  PySRFunction(X=>3.1395071020704912*x15 + x23**...                 4
#
#                                               variables  number_variables  \
# 0                                               {'x66'}                 1
# 1                                               {'x73'}                 1
# 2                                 {'x53', 'x69', 'x42'}                 3
# 3                                 {'x53', 'x69', 'x42'}                 3
# 4                          {'x53', 'x69', 'x42', 'x51'}                 4
# ...                                                 ...               ...
# 1017  {'x42', 'x79', 'x19', 'x39', 'x15', 'x64', 'x1...                 8
# 1018  {'x42', 'x19', 'x23', 'x39', 'x15', 'x64', 'x28'}                 7
# 1019                                     {'x42', 'x15'}                 2
# 1020                       {'x19', 'x42', 'x15', 'x39'}                 4
# 1021                {'x42', 'x19', 'x23', 'x39', 'x15'}                 6
#
#       unique_number_variables  ...  \
# 0                           1  ...
# 1                           1  ...
# 2                           3  ...
# 3                           3  ...
# 4                           4  ...
# ...                       ...  ...
# 1017                        8  ...
# 1018                        7  ...
# 1019                        2  ...
# 1020                        4  ...
# 1021                        5  ...
#
#                                          fitting_format  \
# 0                                                   x66
# 1                                            x73 + p[0]
# 2                          -p[0]*x42 + x53 + x69 + p[1]
# 3                          -p[1]*x42 + x53 + x69 + p[0]
# 4     -p[1]*x42 + x53 + x69 + p[0] - p[2]/(p[3]*x51 ...
# ...                                                 ...
# 1017  p[2]*x15 + (x39 - x42)/(x17/(x28*x64) + exp(x1...
# 1018  p[3]*x15 + x23**(-p[0]) + (x39 - x42)/(exp(x19...
# 1019                            (p[0] - x42)*log10(x15)
# 1020            p[1]*x15 + (x39 - x42)*exp(-x19) + p[0]
# 1021  p[3]*x15 + x23**(-p[0]) + (x39 - x42)/(exp(x19...
#
#       num_fitting_variables  \
# 0                         0
# 1                         1
# 2                         2
# 3                         2
# 4                         5
# ...                     ...
# 1017                      3
# 1018                      4
# 1019                      1
# 1020                      2
# 1021                      4
#
#                                  initial_constant_guess          LLL  \
# 0                                                    [] -1424.139485
# 1                                  ['8.37716156751411']  -503.997916
# 2            ['0.450188413619603', '0.298028247506404']   -90.130444
# 3            ['0.396106010486694', '0.465246509398211']   -92.883246
# 4     ['0.457313122948769', '0.450188413619603', '0....   -90.686958
# ...                                                 ...          ...
# 1017  ['0.000395449818763269', '0.28986004884971', '...    -3.045656
# 1018  ['0.000395449818763269', '0.28986004884971', '...    -5.116673
# 1019                               ['26.0373297032021']   -57.242537
# 1020          ['0.662538219789564', '3.13950710207049']    -6.039985
# 1021  ['0.000395449818763269', '0.28986004884971', '...    -1.394339
#
#      intrinsic_scatter                                     refit_equation  \
# 0             1.830990                                                x66
# 1             1.069723                            x73 + 8.120512184890048
# 2             0.476856  -0.3753177359347113*x42 + x53 + x69 + 0.067348...
# 3             0.476855  -0.37531951644419825*x42 + x53 + x69 + 0.06735...
# 4             0.454678  -0.4229420667397843*x42 + x53 + x69 + 0.474344...
# ...                ...                                                ...
# 1017          0.140435  2.9878660600448335*x15 + (x39 - x42)/(x17/(x28...
# 1018          0.146195  2.9220140196249513*x15 + x23**(--0.01158307249...
# 1019          0.379120              (25.844373617613577 - x42)*log10(x15)
# 1020          0.166918  2.849756961078741*x15 + (x39 - x42)*exp(-x19) ...
# 1021          0.127128  3.0440584383966294*x15 + x23**(-0.001880592940...
#
#       refit_wrmse          AIC          BIC  DOF
# 0        2.422899  2850.278970  2857.344169    2
# 1        0.858892  1011.995832  1017.061031    2
# 2        0.096992   190.260888   202.923886    5
# 3        0.096992   199.766493   217.494689    7
# 4        0.091732   195.373916   213.102113    7
# ...           ...          ...          ...  ...
# 1017     0.011424    14.091311    46.884707    9
# 1018     0.011319    20.233347    46.494143    8
# 1019     0.048948   118.485073   128.082872    3
# 1020     0.013362    18.079970    34.742967    5
# 1021     0.009564    12.788679    29.984276    6
#
# [1022 rows x 22 columns]
