# %%
import numpy as np
import pandas as pd
from pysr import PySRRegressor
from IPython.display import HTML
from matplotlib import pyplot as plt

from hyperfit.linfit import LinFit

import functions
import old_relations
import new_relations

# %% [markdown]
# \begin{equation}
# \log (\frac{{M}_{BH}}{{M}_\odot})= (\log \sigma_0 + 1.40)(\log v_{max} -\tan \phi))
# \end{equation}

# %%
functions.plot_relation(['log_sigma0','tan_phi','log_v_max'],new_relations.sigma_phi_v_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= (\log \sigma_0 + 1.40)(\logv_{max}-\tan\phi)$',
                       reference_relation=old_relations.m_sigma_IMBH_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 5.82 \log (\frac{\sigma_0}{200})+8.17$')
# Out:
# 41
# N-D relation wrmse: 0.27820990325942074
# 1-D relation wrmse: 0.4846167822437608

# %%
functions.plot_relation(['log_sigma0','tan_phi','log_v_max'],new_relations.sigma_phi_v_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= (\log \sigma_0 + 1.40)(\logv_{max}-\tan\phi)$',
                       reference='tan_phi',reference_relation=old_relations.m_phi_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 7.01-0.171(\phi-15^\circ)$')
# Out:
# 41
# N-D relation wrmse: 0.27820990325942074
# 1-D relation wrmse: 0.4058662835403836

# %%
functions.plot_relation(['log_sigma0','tan_phi','log_v_max'],new_relations.sigma_phi_v_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= (\log \sigma_0 + 1.40)(\logv_{max}-\tan\phi)$',
                       reference='log_v_max',reference_relation=old_relations.m_vmax_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 10.62 \log (\frac{v_{max}}{210})+7.22$')
# Out:
# 41
# N-D relation wrmse: 0.27820990325942074
# 1-D relation wrmse: 0.42787700508547555

# %% [markdown]
# \begin{equation}
# \log (\frac{{M}_{BH}}{{M}_\odot})= 3.89 (\log \sigma_0 - \tan\phi)
# \end{equation}

# %%
functions.plot_relation(['log_sigma0','tan_phi'],new_relations.sigma_phi_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 3.89 (\log \sigma_0 - \tan\phi)$',
                       reference_relation=old_relations.m_sigma_IMBH_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 5.82 \log (\frac{\sigma_0}{200})+8.17$')
# Out:
# 47
# N-D relation wrmse: 0.340965900049914
# 1-D relation wrmse: 0.47929122301367616

# %%
functions.plot_relation(['log_sigma0','tan_phi'],new_relations.sigma_phi_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 3.89 (\log \sigma_0 - \tan\phi)$',
                       reference='tan_phi',reference_relation=old_relations.m_phi_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 7.01-0.171(\phi-15^\circ)$')
# Out:
# 47
# N-D relation wrmse: 0.340965900049914
# 1-D relation wrmse: 0.4133020326209189

# %% [markdown]
# \begin{equation}
# \log (\frac{{M}_{BH}}{{M}_\odot})= 1.51 \log v_{max}(\log v_{max}-\tan\phi)
# \end{equation}

# %%
functions.plot_relation(['tan_phi','log_v_max'],new_relations.phi_v_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 1.51 \log v_{max}(\log v_{max}-\tan\phi) $',
                       reference='log_v_max',reference_relation=old_relations.m_vmax_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 10.62 \log (\frac{v_{max}}{210})+7.22$')
# Out:
# 42
# N-D relation wrmse: 0.3216906148489129
# 1-D relation wrmse: 0.4278506220992225

# %%
functions.plot_relation(['tan_phi','log_v_max'],new_relations.phi_v_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 1.51 \log v_{max}(\log v_{max}-\tan\phi) $',
                       reference='tan_phi',reference_relation=old_relations.m_phi_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 7.01-0.171(\phi-15^\circ)$')
# Out:
# 42
# N-D relation wrmse: 0.3216906148489129
# 1-D relation wrmse: 0.4058537080339953

# %% [markdown]
# \begin{equation}
# \log (\frac{{M}_{BH}}{{M}_\odot})= \frac{8.93+\frac{0.61 \tan\phi}{M^*_{gal}(M^*_{gal}-\frac{2.50}{\tan\phi})}}{\tan\phi+0.98}
# \end{equation}

# %%
functions.plot_relation(['M*_gal','tan_phi'],new_relations.mgal_phi_relation,labelamp=1.0,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= \frac{8.93+\frac{0.61 \tan\phi}{M^*_{gal}(M^*_{gal}-\frac{2.50}{\tan\phi})}}{\tan\phi+0.98}$',
                       reference='M*_gal',reference_relation=old_relations.m_mgal_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=3.23 \log (M^*_{sph}/10^{11}) + 7.91$')
# Out:
# 44
# N-D relation wrmse: 0.25342988968654245
# 1-D relation wrmse: 0.7462610503466154

# %%
functions.plot_relation(['M*_gal','tan_phi'],new_relations.mgal_phi_relation,labelamp=1.0,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= \frac{8.93+\frac{0.61 \tan\phi}{M^*_{gal}(M^*_{gal}-\frac{2.50}{\tan\phi})}}{\tan\phi+0.98}$',
                       reference='tan_phi',reference_relation=old_relations.m_phi_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 7.01-0.171(\phi-15^\circ)$')
# Out:
# 44
# N-D relation wrmse: 0.25342988968654245
# 1-D relation wrmse: 0.40960096803925106
