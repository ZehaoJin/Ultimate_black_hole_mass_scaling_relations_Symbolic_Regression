# %%
import numpy as np
import pandas as pd
from pysr import PySRRegressor
from IPython.display import HTML
from matplotlib import pyplot as plt

from hyperfit.linfit import LinFit

import functions
import old_relations
import new_relations

# %% [markdown]
# ## Low-scatter ones

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})=\alpha \log (\frac{\sigma_0}{189}) + \beta \log (\frac{B/T}{0.437}) + \gamma \log (\frac{\rho_\text{soi}}{601}) + \delta
# \end{equation}

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})=2.85 \log (\frac{\sigma_0}{189}) + 1.16 \log (\frac{B/T}{0.437}) - 0.33 \log (\frac{\rho_\text{soi}}{601}) + 8.20
# \end{equation}

# %%
functions.plot_relation(['log_sigma0','log_B/T','logRho_soi_approx_new'],new_relations.sigma_bt_rho_normalized_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=2.85 \log (\frac{\sigma_0}{189}) + 1.16 \log (\frac{B/T}{0.437}) - 0.33 \log (\frac{\rho_{soi}}{601}) + 8.20$'
                       ,bins=8)
# Out:
# 122
# N-D relation wrmse: 0.269626123045062
# 1-D relation wrmse: 0.46322183667235833

# %%
functions.plot_relation(['log_sigma0','log_B/T','logRho_soi_approx_new'],new_relations.sigma_bt_rho_normalized_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=2.85 \log (\frac{\sigma_0}{189}) + 1.16 \log (\frac{B/T}{0.437}) - 0.33 \log (\frac{\rho_{soi}}{601}) + 8.20$',
                        reference='log_B/T',reference_relation=old_relations.m_bt_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=2.40 \log(B/T) + 9.11$',
                        bins=8)
# Out:
# 122
# N-D relation wrmse: 0.269626123045062
# 1-D relation wrmse: 0.5694280168190083

# %%
functions.plot_relation(['log_sigma0','log_B/T','logRho_soi_approx_new'],new_relations.sigma_bt_rho_normalized_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=2.85 \log (\frac{\sigma_0}{189}) + 1.16 \log (\frac{B/T}{0.437}) - 0.33 \log (\frac{\rho_{soi}}{601}) + 8.20$',
                        reference='logRho_soi_approx_new',reference_relation=old_relations.m_rho_soi_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=-0.93 \log \rho_{soi} + 10.64$')
# Out:
# 122
# N-D relation wrmse: 0.269626123045062
# 1-D relation wrmse: 0.7111573735686504

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})=2.57 \log \sigma_0 + 0.38 (\log R_e - \log \rho_\text{soi}) + bvc + 2.61
# \end{equation}

# %%
functions.plot_relation(['log_sigma0','log_R_e_sph_eq_kpc','logRho_soi_approx_new','bvtc'],new_relations.sigma_r_rho_bvc_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=2.57 \log \sigma_0 + 0.38 (\log R_e - \log \rho_{soi}) + bvc + 2.61$')
# Out:
# 104
# N-D relation wrmse: 0.2555909819014655
# 1-D relation wrmse: 0.4611226817451731

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})=2.57 \log \sigma_0 + \log(B/T) - 0.43 \log \rho_\text{soi} - 0.24 \ \text{Pseudobulge} + 4.01
# \end{equation}

# %%
functions.plot_relation(['log_sigma0','log_B/T','logRho_soi_approx_new','Pseudobulge'],new_relations.sigma_bt_rho_pseudobulge_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=2.57 \log \sigma_0 + \log(B/T) - 0.43 \log \rho_{soi} - 0.24 \ {Pseudobulge} + 4.01$')
# Out:
# 122
# N-D relation wrmse: 0.22683915270235738
# 1-D relation wrmse: 0.46322183667235833

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})=3 \log \sigma_0 - (\log \rho_\text{soi})^{0.58} + e^{\log(B/T)-\text{Pseudobulge}} + 2.55
# \end{equation}

# %%
functions.plot_relation(['log_sigma0','logRho_soi_approx_new','log_B/T','Pseudobulge'],new_relations.sigma_rho_bt_pseudobulge_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=3 \log \sigma_0 - (\log \rho_{soi})^{0.58} + e^{\log(B/T)-{Pseudobulge}} + 2.55$')
# Out:
# 122
# N-D relation wrmse: 0.224195290778272
# 1-D relation wrmse: 0.46322183667235833

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})=0.91 \log \text{M}^{*}_{\text{sph}} - 0.41(\log \rho_\text{soi}+\text{Pseudobulge}) - 0.27
# \end{equation}

# %%
functions.plot_relation(['M*_sph','logRho_soi_approx_new','Pseudobulge'],new_relations.Msph_rho_pseudobulge_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=0.91 \log {M}^{*}_{{sph}} - 0.41(\log \rho_{soi}+{Pseudobulge}) - 0.27$',
                        reference='M*_sph',reference_relation=old_relations.m_msph_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=1.31 \log M^*_{sph} - 5.83$')
# Out:
# 122
# N-D relation wrmse: 0.3042698714063203
# 1-D relation wrmse: 0.42717249549674524

# %% [markdown]
# ## Easy-to-use Ones

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})= \log L_{B}-\frac{1.73}{bvc}
# \end{equation}

# %%
functions.plot_relation(['logblum','bvtc'],new_relations.blum_bvc_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= \log L_{B}-\frac{1.73}{bvc}$',
                       reference='logblum',reference_relation=old_relations.m_blum_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=1.94 \log L_{B} -12.07603801$')
# Out:
# 122
# N-D relation wrmse: 0.518232036988227
# 1-D relation wrmse: 0.8106798856668046

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})= 0.44^{bvc} + \log L_{B} - 5.52
# \end{equation}

# %%
functions.plot_relation(['bvtc','logblum'],new_relations.bvc_blum_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= 0.44^{bvc} + \log L_{B} - 5.52$',
                       reference='logblum',reference_relation=old_relations.m_blum_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=1.94 \log L_{B} -12.07603801$')
# Out:
# 122
# N-D relation wrmse: 0.44358961729746454
# 1-D relation wrmse: 0.8106798856668046

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})=\log \sigma_0 (3.61 + 0.23(\text{Core}-\text{Pseudobulge}))
# \end{equation}

# %%
functions.plot_relation(['log_sigma0','Core','Pseudobulge'],new_relations.sigma_core_pseudobulge,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=\log \sigma_0 (3.61 + 0.23({Core}-{Pseudobulge}))$')
# Out:
# 143
# N-D relation wrmse: 0.31063427354159756
# 1-D relation wrmse: 0.45358885734290577

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})=4.14 \log \sigma_0 + 0.45 (\text{Core}-\text{Pseudobulge})-1.14
# \end{equation}

# %%
functions.plot_relation(['log_sigma0','Core','Pseudobulge'],new_relations.sigma_core_pseudobulge2,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=4.14 \log \sigma_0 + 0.45 ({Core}-{Pseudobulge})-1.14$')
# Out:
# 143
# N-D relation wrmse: 0.3122572996245162
# 1-D relation wrmse: 0.45358885734290577

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})= \log \text{M}^{*}_{\text{sph}} + 0.36 (\text{Core}-\text{Pseudobulge}) -2.42
# \end{equation}

# %%
functions.plot_relation(['M*_sph','Core','Pseudobulge'],new_relations.Msph_core_pseudobulge,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= \log {M}^{*}_{{sph}} + 0.36 ({Core}-{Pseudobulge}) -2.42$',
                      reference='M*_sph',reference_relation=old_relations.m_msph_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=1.31 \log M^*_{sph} - 5.83$')
# Out:
# 124
# N-D relation wrmse: 0.3632718495652039
# 1-D relation wrmse: 0.44837110383115697

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})= \log \text{M}^{*}_{\text{sph}} + 0.33 (\text{Core}-\text{Pseudobulge}) + 0.17 bvc -2.54
# \end{equation}

# %%
functions.plot_relation(['M*_sph','Core','Pseudobulge','bvtc'],new_relations.Msph_core_pseudobulge_bvc,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= \log {M}^{*}_{{sph}} + 0.33 ({Core}-{Pseudobulge}) + 0.17 bvc -2.54$',
                       reference='M*_sph',reference_relation=old_relations.m_msph_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=1.31 \log M^*_{sph} - 5.83$')
# Out:
# 105
# N-D relation wrmse: 0.31053997487094576
# 1-D relation wrmse: 0.3832334743961509

# %% [markdown]
# \begin{equation}
# \log (\frac{\text{M}_\text{BH}}{\text{M}_\odot})= \log R_e + 0.67 \text{Core} + bvc + 7.06
# \end{equation}

# %%
functions.plot_relation(['log_R_e_sph_eq_kpc','Core','bvtc'],new_relations.Re_core_bvc_relation,label=r'$\log (\frac{{M}_{BH}}{{M}_\odot})= \log R_e + 0.67 {Core} + bvc + 7.06$',
                       reference='log_R_e_sph_eq_kpc',reference_relation=old_relations.m_Re_relation,reference_name=r'$\log (\frac{{M}_{BH}}{{M}_\odot})=1.63 \log R_{e} + 7.68$')
# Out:
# 107
# N-D relation wrmse: 0.39393209165364523
# 1-D relation wrmse: 0.5356653762633925
